# %%
import os
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
#---------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
#---------------------------------------
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
#---------------------------------------
import logging
import warnings
logging.getLogger().setLevel(logging.ERROR)
warnings.filterwarnings("ignore")
warnings.simplefilter('ignore')
# Out:
# 2025-04-15 16:03:16.695612: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-15 16:03:16.702583: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744711396.710357  470806 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744711396.712710  470806 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1744711396.718928  470806 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744711396.718934  470806 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744711396.718935  470806 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744711396.718961  470806 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-15 16:03:16.721472: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Load Training Data

# %%
def train_df(tr_path):
    classes, class_paths = zip(*[(label, os.path.join(tr_path, label, image))
                                 for label in os.listdir(tr_path) if os.path.isdir(os.path.join(tr_path, label))
                                 for image in os.listdir(os.path.join(tr_path, label))])

    tr_df = pd.DataFrame({'Class Path': class_paths, 'Class': classes})
    return tr_df

# %%
tr_df = train_df('/home/readinggroup/Desktop/K_venv/dl/MRI/Training')
tr_df
# Out:
#                                              Class Path       Class
# 0     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# 1     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# 2     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# 3     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# 4     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# ...                                                 ...         ...
# 5707  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
# 5708  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
# 5709  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
# 5710  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
# 5711  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
#
# [5712 rows x 2 columns]

# %% [markdown]
# # Load Test Data

# %%
def test_df(ts_path):
    classes, class_paths = zip(*[(label, os.path.join(ts_path, label, image))
                                 for label in os.listdir(ts_path) if os.path.isdir(os.path.join(ts_path, label))
                                 for image in os.listdir(os.path.join(ts_path, label))])

    ts_df = pd.DataFrame({'Class Path': class_paths, 'Class': classes})
    return ts_df

# %%
ts_df = test_df('/home/readinggroup/Desktop/K_venv/dl/MRI/Testing')
ts_df
# Out:
#                                              Class Path       Class
# 0     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 1     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 2     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 3     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 4     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# ...                                                 ...         ...
# 1306  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 1307  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 1308  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 1309  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 1310  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
#
# [1311 rows x 2 columns]

# %% [markdown]
# # Number of images in each class in train data

# %%
plt.figure(figsize=(15,7))
ax = sns.countplot(data=tr_df , y=tr_df['Class'])

plt.xlabel('')
plt.ylabel('')
plt.title('Count of images in each class', fontsize=20)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# # Count each class in test data

# %%
plt.figure(figsize=(15,7))
ax = sns.countplot(data=ts_df , y=ts_df['Class'])

plt.xlabel('')
plt.ylabel('')
plt.title('Count of images in each class', fontsize=20)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# # Splitting dataset

# %%
valid_df, ts_df = train_test_split(ts_df, train_size=0.5, random_state=20, stratify=ts_df['Class'])
valid_df
# Out:
#                                              Class Path       Class
# 1297  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 18    /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 367   /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...   pituitary
# 73    /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 1120  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# ...                                                 ...         ...
# 1070  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 860   /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...     notumor
# 1284  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 194   /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 932   /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...     notumor
#
# [655 rows x 2 columns]

# %% [markdown]
# # Data preprocessing

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input

batch_size = 32
img_size = (299, 299)
seed = 42

# Augmentation for training
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.15,
    zoom_range=0.1,
    horizontal_flip=True,
    brightness_range=(0.8, 1.2),
    fill_mode='nearest'
)

# No augmentation for validation and test
test_val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# Train generator
tr_gen = train_datagen.flow_from_dataframe(
    dataframe=tr_df,
    x_col='Class Path',
    y_col='Class',
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb',
    seed=seed
)

# Validation generator
valid_gen = test_val_datagen.flow_from_dataframe(
    dataframe=valid_df,
    x_col='Class Path',
    y_col='Class',
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=False,
    seed=seed
)

# Test generator
ts_gen = test_val_datagen.flow_from_dataframe(
    dataframe=ts_df,
    x_col='Class Path',
    y_col='Class',
    target_size=img_size,
    batch_size=16,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=False,
    seed=seed
)

print("Class indices:", tr_gen.class_indices)
# Out:
# Found 5712 validated image filenames belonging to 4 classes.
# Found 655 validated image filenames belonging to 4 classes.
# Found 656 validated image filenames belonging to 4 classes.
# Class indices: {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}

# %% [markdown]
# # Getting samples from data

# %%
class_dict = tr_gen.class_indices
classes = list(class_dict.keys())
images, labels = next(ts_gen)

plt.figure(figsize=(20, 20))

for i, (image, label) in enumerate(zip(images, labels)):
    plt.subplot(4, 4, i + 1)

    image_vis = (image + 1.0) / 2.0
    image_vis = np.clip(image_vis, 0, 1)

    plt.imshow(image_vis)
    class_name = classes[np.argmax(label)]
    plt.title(class_name, color='k', fontsize=15)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Building the model

# %%
from tensorflow.keras.optimizers.schedules import ExponentialDecay

# Image shape for EfficientNetV2B1
img_shape = (299, 299, 3)

# Load EfficientNetV2B1 as base model
base_model = tf.keras.applications.EfficientNetV2B1(
    weights='imagenet',
    include_top=False,
    input_shape=img_shape
)

# Fine-tune: freeze only early layers
base_model.trainable = True
for layer in base_model.layers[:200]:
    layer.trainable = False

# Define the model
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    BatchNormalization(),
    Dropout(0.3),
    Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    Dropout(0.25),
    Dense(4, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2(0.01))
])

# Learning rate schedule
lr_schedule = ExponentialDecay(
    initial_learning_rate=1e-4,
    decay_steps=1000,
    decay_rate=0.9
)

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='categorical_crossentropy',
    metrics=['accuracy', Precision(), Recall()]
)

model.summary()
# Out:
# I0000 00:00:1744711398.163232  470806 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1011 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetv2-b1 (Functional)  │ (None, 10, 10, 1280)   │     6,931,124 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,100,728 (27.09 MB)
#  Trainable params: 5,146,656 (19.63 MB)
#  Non-trainable params: 1,954,072 (7.45 MB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %% [markdown]
# # Training

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

hist = model.fit(tr_gen,
                 epochs=1000,
                 validation_data=valid_gen,
                 shuffle= False,
                 callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744711408.113520  470955 service.cc:152] XLA service 0x7b0bdc001bf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1744711408.113534  470955 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4080, Compute Capability 8.9
# 2025-04-15 16:03:28.430964: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1744711409.980179  470955 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-04-15 16:03:31.977865: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 790.02MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-15 16:03:32.356708: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 666.14MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-15 16:03:32.416769: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.03GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-15 16:03:33.538704: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 16:03:33.619275: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   1/179 ━━━━━━━━━━━━━━━━━━━━ 57:52 20s/step - accuracy: 0.1562 - loss: 4.9612 - precision: 0.1481 - recall: 0.1250
# I0000 00:00:1744711419.115688  470955 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.6463 - loss: 3.3521 - precision: 0.6844 - recall: 0.5991
# 2025-04-15 16:04:18.254056: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 796.02MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-15 16:04:18.667462: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 628.25MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-15 16:04:18.700915: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 655.91MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-15 16:04:18.760200: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 730.29MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.6469 - loss: 3.3500 - precision: 0.6851 - recall: 0.5999
# 2025-04-15 16:04:26.192124: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2894', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-04-15 16:04:28.382471: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2894', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-04-15 16:04:28.818452: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 779.77MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-15 16:04:29.217552: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 623.46MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-15 16:04:29.248154: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 654.98MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 71s 289ms/step - accuracy: 0.6476 - loss: 3.3480 - precision: 0.6857 - recall: 0.6006 - val_accuracy: 0.8870 - val_loss: 2.6252 - val_precision: 0.9340 - val_recall: 0.8214
# Epoch 2/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.8955 - loss: 2.5158 - precision: 0.9094 - recall: 0.8856 - val_accuracy: 0.9450 - val_loss: 2.2419 - val_precision: 0.9535 - val_recall: 0.9389
# Epoch 3/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9227 - loss: 2.2645 - precision: 0.9283 - recall: 0.9158 - val_accuracy: 0.9588 - val_loss: 2.0155 - val_precision: 0.9646 - val_recall: 0.9557
# Epoch 4/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9486 - loss: 2.0258 - precision: 0.9550 - recall: 0.9449 - val_accuracy: 0.9740 - val_loss: 1.8244 - val_precision: 0.9755 - val_recall: 0.9740
# Epoch 5/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9522 - loss: 1.8269 - precision: 0.9574 - recall: 0.9487 - val_accuracy: 0.9802 - val_loss: 1.6341 - val_precision: 0.9832 - val_recall: 0.9802
# Epoch 6/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9725 - loss: 1.6156 - precision: 0.9736 - recall: 0.9697 - val_accuracy: 0.9847 - val_loss: 1.4605 - val_precision: 0.9847 - val_recall: 0.9817
# Epoch 7/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9714 - loss: 1.4560 - precision: 0.9736 - recall: 0.9695 - val_accuracy: 0.9908 - val_loss: 1.3010 - val_precision: 0.9908 - val_recall: 0.9893
# Epoch 8/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9803 - loss: 1.2951 - precision: 0.9815 - recall: 0.9783 - val_accuracy: 0.9878 - val_loss: 1.1623 - val_precision: 0.9878 - val_recall: 0.9878
# Epoch 9/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9826 - loss: 1.1465 - precision: 0.9856 - recall: 0.9816 - val_accuracy: 0.9908 - val_loss: 1.0300 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 10/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9821 - loss: 1.0175 - precision: 0.9839 - recall: 0.9788 - val_accuracy: 0.9954 - val_loss: 0.9014 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 11/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9845 - loss: 0.8989 - precision: 0.9856 - recall: 0.9822 - val_accuracy: 0.9939 - val_loss: 0.7993 - val_precision: 0.9939 - val_recall: 0.9924
# Epoch 12/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9872 - loss: 0.7968 - precision: 0.9874 - recall: 0.9865 - val_accuracy: 0.9924 - val_loss: 0.7077 - val_precision: 0.9924 - val_recall: 0.9924
# Epoch 13/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.9866 - loss: 0.7009 - precision: 0.9873 - recall: 0.9861 - val_accuracy: 0.9939 - val_loss: 0.6207 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 14/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9911 - loss: 0.6138 - precision: 0.9920 - recall: 0.9906 - val_accuracy: 0.9969 - val_loss: 0.5429 - val_precision: 0.9969 - val_recall: 0.9954
# Epoch 15/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9901 - loss: 0.5370 - precision: 0.9904 - recall: 0.9884 - val_accuracy: 0.9939 - val_loss: 0.4828 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 16/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9887 - loss: 0.4751 - precision: 0.9913 - recall: 0.9884 - val_accuracy: 0.9985 - val_loss: 0.4189 - val_precision: 0.9985 - val_recall: 0.9969
# Epoch 17/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9901 - loss: 0.4177 - precision: 0.9913 - recall: 0.9894 - val_accuracy: 0.9939 - val_loss: 0.3749 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 18/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9942 - loss: 0.3602 - precision: 0.9953 - recall: 0.9935 - val_accuracy: 0.9969 - val_loss: 0.3217 - val_precision: 0.9969 - val_recall: 0.9969
# Epoch 19/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9929 - loss: 0.3203 - precision: 0.9933 - recall: 0.9917 - val_accuracy: 0.9924 - val_loss: 0.3003 - val_precision: 0.9924 - val_recall: 0.9924
# Epoch 20/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9905 - loss: 0.2894 - precision: 0.9912 - recall: 0.9898 - val_accuracy: 0.9939 - val_loss: 0.2590 - val_precision: 0.9939 - val_recall: 0.9924
# Epoch 21/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9943 - loss: 0.2469 - precision: 0.9948 - recall: 0.9942 - val_accuracy: 0.9939 - val_loss: 0.2258 - val_precision: 0.9939 - val_recall: 0.9924
# Epoch 22/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9939 - loss: 0.2211 - precision: 0.9946 - recall: 0.9938 - val_accuracy: 0.9954 - val_loss: 0.1994 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 23/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9906 - loss: 0.2006 - precision: 0.9916 - recall: 0.9892 - val_accuracy: 0.9924 - val_loss: 0.1866 - val_precision: 0.9939 - val_recall: 0.9908
# Epoch 24/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.9941 - loss: 0.1776 - precision: 0.9948 - recall: 0.9940 - val_accuracy: 0.9954 - val_loss: 0.1632 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 25/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9966 - loss: 0.1537 - precision: 0.9969 - recall: 0.9961 - val_accuracy: 0.9969 - val_loss: 0.1439 - val_precision: 0.9969 - val_recall: 0.9954
# Epoch 26/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9961 - loss: 0.1384 - precision: 0.9965 - recall: 0.9961 - val_accuracy: 0.9954 - val_loss: 0.1403 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 27/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9946 - loss: 0.1293 - precision: 0.9952 - recall: 0.9941 - val_accuracy: 0.9939 - val_loss: 0.1254 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 28/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9941 - loss: 0.1185 - precision: 0.9942 - recall: 0.9936 - val_accuracy: 0.9924 - val_loss: 0.1187 - val_precision: 0.9924 - val_recall: 0.9908
# Epoch 29/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9931 - loss: 0.1118 - precision: 0.9938 - recall: 0.9928 - val_accuracy: 0.9908 - val_loss: 0.1083 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 30/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9968 - loss: 0.0953 - precision: 0.9974 - recall: 0.9966 - val_accuracy: 0.9939 - val_loss: 0.0982 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 31/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9949 - loss: 0.0945 - precision: 0.9953 - recall: 0.9943 - val_accuracy: 0.9939 - val_loss: 0.0957 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 32/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9972 - loss: 0.0803 - precision: 0.9979 - recall: 0.9964 - val_accuracy: 0.9939 - val_loss: 0.0954 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 33/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9944 - loss: 0.0804 - precision: 0.9952 - recall: 0.9943 - val_accuracy: 0.9939 - val_loss: 0.0817 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 34/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9935 - loss: 0.0780 - precision: 0.9936 - recall: 0.9931 - val_accuracy: 0.9939 - val_loss: 0.0835 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 35/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9971 - loss: 0.0682 - precision: 0.9976 - recall: 0.9967 - val_accuracy: 0.9939 - val_loss: 0.0759 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 36/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9986 - loss: 0.0631 - precision: 0.9986 - recall: 0.9986 - val_accuracy: 0.9954 - val_loss: 0.0822 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 37/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9937 - loss: 0.0669 - precision: 0.9941 - recall: 0.9936 - val_accuracy: 0.9939 - val_loss: 0.0786 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 38/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9975 - loss: 0.0561 - precision: 0.9979 - recall: 0.9975 - val_accuracy: 0.9954 - val_loss: 0.0691 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 39/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9970 - loss: 0.0561 - precision: 0.9970 - recall: 0.9967 - val_accuracy: 0.9924 - val_loss: 0.0739 - val_precision: 0.9924 - val_recall: 0.9924
# Epoch 40/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9978 - loss: 0.0524 - precision: 0.9978 - recall: 0.9978 - val_accuracy: 0.9954 - val_loss: 0.0671 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 41/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9966 - loss: 0.0521 - precision: 0.9976 - recall: 0.9966 - val_accuracy: 0.9954 - val_loss: 0.0710 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 42/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9978 - loss: 0.0516 - precision: 0.9978 - recall: 0.9970 - val_accuracy: 0.9954 - val_loss: 0.0621 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 43/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9958 - loss: 0.0510 - precision: 0.9969 - recall: 0.9948 - val_accuracy: 0.9954 - val_loss: 0.0625 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 44/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9983 - loss: 0.0469 - precision: 0.9984 - recall: 0.9978 - val_accuracy: 0.9969 - val_loss: 0.0545 - val_precision: 0.9969 - val_recall: 0.9969
# Epoch 45/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9971 - loss: 0.0456 - precision: 0.9976 - recall: 0.9965 - val_accuracy: 0.9939 - val_loss: 0.0614 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 46/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9956 - loss: 0.0479 - precision: 0.9957 - recall: 0.9953 - val_accuracy: 0.9954 - val_loss: 0.0545 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 47/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9953 - loss: 0.0491 - precision: 0.9953 - recall: 0.9952 - val_accuracy: 0.9939 - val_loss: 0.0550 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 48/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9955 - loss: 0.0471 - precision: 0.9958 - recall: 0.9955 - val_accuracy: 0.9939 - val_loss: 0.0504 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 49/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9971 - loss: 0.0435 - precision: 0.9971 - recall: 0.9965 - val_accuracy: 0.9954 - val_loss: 0.0428 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 50/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9963 - loss: 0.0438 - precision: 0.9963 - recall: 0.9958 - val_accuracy: 0.9954 - val_loss: 0.0494 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 51/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9976 - loss: 0.0422 - precision: 0.9976 - recall: 0.9973 - val_accuracy: 0.9954 - val_loss: 0.0513 - val_precision: 0.9969 - val_recall: 0.9954
# Epoch 52/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9986 - loss: 0.0379 - precision: 0.9986 - recall: 0.9980 - val_accuracy: 0.9954 - val_loss: 0.0570 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 53/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.9966 - loss: 0.0388 - precision: 0.9972 - recall: 0.9964 - val_accuracy: 0.9954 - val_loss: 0.0523 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 54/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9985 - loss: 0.0366 - precision: 0.9989 - recall: 0.9984 - val_accuracy: 0.9954 - val_loss: 0.0462 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 55/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9975 - loss: 0.0386 - precision: 0.9979 - recall: 0.9975 - val_accuracy: 0.9954 - val_loss: 0.0515 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 56/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9983 - loss: 0.0355 - precision: 0.9987 - recall: 0.9979 - val_accuracy: 0.9954 - val_loss: 0.0536 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 57/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9978 - loss: 0.0370 - precision: 0.9979 - recall: 0.9976 - val_accuracy: 0.9954 - val_loss: 0.0526 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 58/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9990 - loss: 0.0334 - precision: 0.9993 - recall: 0.9987 - val_accuracy: 0.9969 - val_loss: 0.0462 - val_precision: 0.9969 - val_recall: 0.9969
# Epoch 59/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.9986 - loss: 0.0338 - precision: 0.9986 - recall: 0.9985 - val_accuracy: 0.9954 - val_loss: 0.0506 - val_precision: 0.9954 - val_recall: 0.9954

# %% [markdown]
# # Visualize model performance

# %%
hist.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'precision', 'recall', 'val_accuracy', 'val_loss', 'val_precision', 'val_recall'])

# %%
tr_acc = hist.history['accuracy']
tr_loss = hist.history['loss']
tr_per = hist.history['precision']
tr_recall = hist.history['recall']
val_acc = hist.history['val_accuracy']
val_loss = hist.history['val_loss']
val_per = hist.history['val_precision']
val_recall = hist.history['val_recall']

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
index_precision = np.argmax(val_per)
per_highest = val_per[index_precision]
index_recall = np.argmax(val_recall)
recall_highest = val_recall[index_recall]

Epochs = [i + 1 for i in range(len(tr_acc))]
loss_label = f'Best epoch = {str(index_loss + 1)}'
acc_label = f'Best epoch = {str(index_acc + 1)}'
per_label = f'Best epoch = {str(index_precision + 1)}'
recall_label = f'Best epoch = {str(index_recall + 1)}'


plt.figure(figsize=(20, 12))
plt.style.use('fivethirtyeight')


plt.subplot(2, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label='Training loss')
plt.plot(Epochs, val_loss, 'g', label='Validation loss')
plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label='Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy')
plt.scatter(index_acc + 1, acc_highest, s=150, c='blue', label=acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(Epochs, tr_per, 'r', label='Precision')
plt.plot(Epochs, val_per, 'g', label='Validation Precision')
plt.scatter(index_precision + 1, per_highest, s=150, c='blue', label=per_label)
plt.title('Precision and Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(Epochs, tr_recall, 'r', label='Recall')
plt.plot(Epochs, val_recall, 'g', label='Validation Recall')
plt.scatter(index_recall + 1, recall_highest, s=150, c='blue', label=recall_label)
plt.title('Recall and Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.grid(True)

plt.suptitle('Model Training Metrics Over Epochs', fontsize=16)
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
train_score = model.evaluate(tr_gen, verbose=1)
valid_score = model.evaluate(valid_gen, verbose=1)
test_score = model.evaluate(ts_gen, verbose=1)

print(f"Train Loss: {train_score[0]:.4f}")
print(f"Train Accuracy: {train_score[1]*100:.2f}%")
print('-' * 20)
print(f"Validation Loss: {valid_score[0]:.4f}")
print(f"Validation Accuracy: {valid_score[1]*100:.2f}%")
print('-' * 20)
print(f"Test Loss: {test_score[0]:.4f}")
print(f"Test Accuracy: {test_score[1]*100:.2f}%")

print(test_score)
# Out:
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9997 - loss: 0.0317 - precision: 0.9997 - recall: 0.9994
# 2025-04-15 16:40:55.826010: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2894', 12 bytes spill stores, 12 bytes spill loads
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.9997 - loss: 0.0317 - precision: 0.9997 - recall: 0.9994
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9989 - loss: 0.0343 - precision: 0.9989 - recall: 0.9989
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9989 - loss: 0.0335 - precision: 1.0000 - recall: 0.9989
# Train Loss: 0.0316
# Train Accuracy: 99.95%
# --------------------
# Validation Loss: 0.0428
# Validation Accuracy: 99.54%
# --------------------
# Test Loss: 0.0339
# Test Accuracy: 99.85%
# [0.03385351598262787, 0.9984756112098694, 1.0, 0.9984756112098694]

# %%
preds = model.predict(ts_gen)
y_pred = np.argmax(preds, axis=1)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step

# %% [markdown]
# # Confusion matrix

# %%
cm = confusion_matrix(ts_gen.classes, y_pred)
labels = list(class_dict.keys())
plt.figure(figsize=(8,7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('Truth Label')
plt.show()

# %% [markdown]
# # Classification report

# %%
report = classification_report(ts_gen.classes, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       150
#            1       1.00      0.99      1.00       153
#            2       1.00      1.00      1.00       203
#            3       0.99      1.00      1.00       150
#
#     accuracy                           1.00       656
#    macro avg       1.00      1.00      1.00       656
# weighted avg       1.00      1.00      1.00       656

# %% [markdown]
# # Testing

# %%
def predict(img_path):
    import numpy as np
    import matplotlib.pyplot as plt
    from PIL import Image
    from tensorflow.keras.applications.efficientnet_v2 import preprocess_input

    # Generator label order
    labels = list(tr_gen.class_indices.keys())

    plt.figure(figsize=(12, 12))
    img = Image.open(img_path).convert('RGB')
    resized_img = img.resize((299, 299))
    img = np.asarray(resized_img)
    img = np.expand_dims(img, axis=0)

    img = preprocess_input(img)

    predictions = model.predict(img)
    probs = list(predictions[0])

    # Plotting
    plt.subplot(2, 1, 1)
    plt.imshow(resized_img)
    plt.axis('off')
    plt.title("Input Image")

    plt.subplot(2, 1, 2)
    bars = plt.barh(labels, probs, color='skyblue')
    plt.xlabel('Probability', fontsize=15)
    plt.title("Class Probabilities")
    ax = plt.gca()
    ax.bar_label(bars, fmt='%.2f')
    plt.tight_layout()
    plt.show()

# %%
predict('/home/readinggroup/Desktop/K_venv/dl/MRI/Testing/notumor/Te-noTr_0000.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
predict('/home/readinggroup/Desktop/K_venv/dl/MRI/Testing/glioma/Te-glTr_0000.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
predict('/home/readinggroup/Desktop/K_venv/dl/MRI/Testing/pituitary/Te-piTr_0008.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
from numba import cuda
device = cuda.get_current_device()
device.reset()
