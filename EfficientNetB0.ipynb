# %%
import os
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
#---------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
#---------------------------------------
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
#---------------------------------------
import logging
import warnings
logging.getLogger().setLevel(logging.ERROR)
warnings.filterwarnings("ignore")
warnings.simplefilter('ignore')
# Out:
# 2025-04-14 23:25:25.436685: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-14 23:25:25.443681: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744651525.451414  189464 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744651525.453719  189464 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1744651525.459855  189464 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744651525.459863  189464 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744651525.459864  189464 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744651525.459864  189464 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-14 23:25:25.461980: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Load Training Data

# %%
def train_df(tr_path):
    classes, class_paths = zip(*[(label, os.path.join(tr_path, label, image))
                                 for label in os.listdir(tr_path) if os.path.isdir(os.path.join(tr_path, label))
                                 for image in os.listdir(os.path.join(tr_path, label))])

    tr_df = pd.DataFrame({'Class Path': class_paths, 'Class': classes})
    return tr_df

# %%
tr_df = train_df('/home/readinggroup/Desktop/K_venv/dl/MRI/Training')
tr_df
# Out:
#                                              Class Path       Class
# 0     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# 1     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# 2     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# 3     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# 4     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# ...                                                 ...         ...
# 5707  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
# 5708  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
# 5709  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
# 5710  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
# 5711  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
#
# [5712 rows x 2 columns]

# %% [markdown]
# # Load Test Data

# %%
def test_df(ts_path):
    classes, class_paths = zip(*[(label, os.path.join(ts_path, label, image))
                                 for label in os.listdir(ts_path) if os.path.isdir(os.path.join(ts_path, label))
                                 for image in os.listdir(os.path.join(ts_path, label))])

    ts_df = pd.DataFrame({'Class Path': class_paths, 'Class': classes})
    return ts_df

# %%
ts_df = test_df('/home/readinggroup/Desktop/K_venv/dl/MRI/Testing')
ts_df
# Out:
#                                              Class Path       Class
# 0     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 1     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 2     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 3     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 4     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# ...                                                 ...         ...
# 1306  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 1307  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 1308  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 1309  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 1310  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
#
# [1311 rows x 2 columns]

# %% [markdown]
# # Number of images in each class in train data

# %%
plt.figure(figsize=(15,7))
ax = sns.countplot(data=tr_df , y=tr_df['Class'])

plt.xlabel('')
plt.ylabel('')
plt.title('Count of images in each class', fontsize=20)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# # Count each class in test data

# %%
plt.figure(figsize=(15,7))
ax = sns.countplot(data=ts_df , y=ts_df['Class'])

plt.xlabel('')
plt.ylabel('')
plt.title('Count of images in each class', fontsize=20)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# # Splitting dataset

# %%
valid_df, ts_df = train_test_split(ts_df, train_size=0.5, random_state=20, stratify=ts_df['Class'])
valid_df
# Out:
#                                              Class Path       Class
# 1297  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 18    /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 367   /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...   pituitary
# 73    /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 1120  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# ...                                                 ...         ...
# 1070  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 860   /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...     notumor
# 1284  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 194   /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 932   /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...     notumor
#
# [655 rows x 2 columns]

# %% [markdown]
# # Data preprocessing

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input

batch_size = 32
img_size = (300, 300)
seed = 42

# Augmentation for training
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.15,
    zoom_range=0.1,
    horizontal_flip=True,
    brightness_range=(0.8, 1.2),
    fill_mode='nearest'
)

# No augmentation for validation and test
test_val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# Train generator
tr_gen = train_datagen.flow_from_dataframe(
    dataframe=tr_df,
    x_col='Class Path',
    y_col='Class',
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb',
    seed=seed
)

# Validation generator
valid_gen = test_val_datagen.flow_from_dataframe(
    dataframe=valid_df,
    x_col='Class Path',
    y_col='Class',
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=False,
    seed=seed
)

# Test generator
ts_gen = test_val_datagen.flow_from_dataframe(
    dataframe=ts_df,
    x_col='Class Path',
    y_col='Class',
    target_size=img_size,
    batch_size=16,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=False,
    seed=seed
)

print("Class indices:", tr_gen.class_indices)
# Out:
# Found 5712 validated image filenames belonging to 4 classes.
# Found 655 validated image filenames belonging to 4 classes.
# Found 656 validated image filenames belonging to 4 classes.
# Class indices: {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}

# %% [markdown]
# # Getting samples from data

# %%
class_dict = tr_gen.class_indices
classes = list(class_dict.keys())
images, labels = next(ts_gen)

plt.figure(figsize=(20, 20))

for i, (image, label) in enumerate(zip(images, labels)):
    plt.subplot(4, 4, i + 1)

    image_vis = (image + 1.0) / 2.0
    image_vis = np.clip(image_vis, 0, 1)

    plt.imshow(image_vis)
    class_name = classes[np.argmax(label)]
    plt.title(class_name, color='k', fontsize=15)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Building the model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, Activation
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.metrics import Precision, Recall

# Input shape
img_shape = (300, 300, 3)

# Input layer
inputs = Input(shape=img_shape)

# Base model - EfficientNetB0
base_model = EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_tensor=inputs
)

# Freezing for fine-tune the top layers
for layer in base_model.layers[:-30]:  # Fine-tune top 30 layers
    layer.trainable = False

# Feature extractor
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.4)(x)

# Dense block 1
x = Dense(128, kernel_regularizer=l2(0.01))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.3)(x)

# Dense block 2
x = Dense(64, kernel_regularizer=l2(0.01))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.2)(x)

# Output layer (4 classes)
outputs = Dense(4, activation='softmax')(x)

# Build model
model = Model(inputs, outputs)

# Learning rate scheduler
lr_schedule = ExponentialDecay(
    initial_learning_rate=1e-4,
    decay_steps=1000,
    decay_rate=0.9
)

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='categorical_crossentropy',
    metrics=['accuracy', Precision(), Recall()]
)

model.summary()
# Out:
# I0000 00:00:1744651526.881705  189464 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1009 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 300, 300,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 300, 300,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 300, 300,  │          7 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_1         │ (None, 300, 300,  │          0 │ normalization[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_pad       │ (None, 301, 301,  │          0 │ rescaling_1[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 150, 150,  │        864 │ stem_conv_pad[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 150, 150,  │        128 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 150, 150,  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_dwconv      │ (None, 150, 150,  │        288 │ stem_activation[… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_bn          │ (None, 150, 150,  │        128 │ block1a_dwconv[0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_activation  │ (None, 150, 150,  │          0 │ block1a_bn[0][0]  │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_squeeze  │ (None, 32)        │          0 │ block1a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reshape  │ (None, 1, 1, 32)  │          0 │ block1a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reduce   │ (None, 1, 1, 8)   │        264 │ block1a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_expand   │ (None, 1, 1, 32)  │        288 │ block1a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_excite   │ (None, 150, 150,  │          0 │ block1a_activati… │
# │ (Multiply)          │ 32)               │            │ block1a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 150, 150,  │        512 │ block1a_se_excit… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 150, 150,  │         64 │ block1a_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 150, 150,  │      1,536 │ block1a_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 150, 150,  │        384 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 150, 150,  │          0 │ block2a_expand_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_pad  │ (None, 151, 151,  │          0 │ block2a_expand_a… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv      │ (None, 75, 75,    │        864 │ block2a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_bn          │ (None, 75, 75,    │        384 │ block2a_dwconv[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_activation  │ (None, 75, 75,    │          0 │ block2a_bn[0][0]  │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_squeeze  │ (None, 96)        │          0 │ block2a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reshape  │ (None, 1, 1, 96)  │          0 │ block2a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reduce   │ (None, 1, 1, 4)   │        388 │ block2a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_expand   │ (None, 1, 1, 96)  │        480 │ block2a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_excite   │ (None, 75, 75,    │          0 │ block2a_activati… │
# │ (Multiply)          │ 96)               │            │ block2a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 75, 75,    │      2,304 │ block2a_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 75, 75,    │         96 │ block2a_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_conv │ (None, 75, 75,    │      3,456 │ block2a_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn   │ (None, 75, 75,    │        576 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 75, 75,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_dwconv      │ (None, 75, 75,    │      1,296 │ block2b_expand_a… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_bn          │ (None, 75, 75,    │        576 │ block2b_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_activation  │ (None, 75, 75,    │          0 │ block2b_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_squeeze  │ (None, 144)       │          0 │ block2b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reshape  │ (None, 1, 1, 144) │          0 │ block2b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reduce   │ (None, 1, 1, 6)   │        870 │ block2b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_expand   │ (None, 1, 1, 144) │      1,008 │ block2b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_excite   │ (None, 75, 75,    │          0 │ block2b_activati… │
# │ (Multiply)          │ 144)              │            │ block2b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 75, 75,    │      3,456 │ block2b_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn  │ (None, 75, 75,    │         96 │ block2b_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop        │ (None, 75, 75,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add (Add)   │ (None, 75, 75,    │          0 │ block2b_drop[0][… │
# │                     │ 24)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 75, 75,    │      3,456 │ block2b_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 75, 75,    │        576 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 75, 75,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_pad  │ (None, 79, 79,    │          0 │ block3a_expand_a… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv      │ (None, 38, 38,    │      3,600 │ block3a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_bn          │ (None, 38, 38,    │        576 │ block3a_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_activation  │ (None, 38, 38,    │          0 │ block3a_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_squeeze  │ (None, 144)       │          0 │ block3a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reshape  │ (None, 1, 1, 144) │          0 │ block3a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reduce   │ (None, 1, 1, 6)   │        870 │ block3a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_expand   │ (None, 1, 1, 144) │      1,008 │ block3a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_excite   │ (None, 38, 38,    │          0 │ block3a_activati… │
# │ (Multiply)          │ 144)              │            │ block3a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 38, 38,    │      5,760 │ block3a_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 38, 38,    │        160 │ block3a_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_conv │ (None, 38, 38,    │      9,600 │ block3a_project_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn   │ (None, 38, 38,    │        960 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 38, 38,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_dwconv      │ (None, 38, 38,    │      6,000 │ block3b_expand_a… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_bn          │ (None, 38, 38,    │        960 │ block3b_dwconv[0… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_activation  │ (None, 38, 38,    │          0 │ block3b_bn[0][0]  │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_squeeze  │ (None, 240)       │          0 │ block3b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reshape  │ (None, 1, 1, 240) │          0 │ block3b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block3b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_expand   │ (None, 1, 1, 240) │      2,640 │ block3b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_excite   │ (None, 38, 38,    │          0 │ block3b_activati… │
# │ (Multiply)          │ 240)              │            │ block3b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 38, 38,    │      9,600 │ block3b_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn  │ (None, 38, 38,    │        160 │ block3b_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop        │ (None, 38, 38,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add (Add)   │ (None, 38, 38,    │          0 │ block3b_drop[0][… │
# │                     │ 40)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_conv │ (None, 38, 38,    │      9,600 │ block3b_add[0][0] │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn   │ (None, 38, 38,    │        960 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 38, 38,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv_pad  │ (None, 39, 39,    │          0 │ block4a_expand_a… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv      │ (None, 19, 19,    │      2,160 │ block4a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn          │ (None, 19, 19,    │        960 │ block4a_dwconv[0… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation  │ (None, 19, 19,    │          0 │ block4a_bn[0][0]  │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze  │ (None, 240)       │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape  │ (None, 1, 1, 240) │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand   │ (None, 1, 1, 240) │      2,640 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite   │ (None, 19, 19,    │          0 │ block4a_activati… │
# │ (Multiply)          │ 240)              │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 19, 19,    │     19,200 │ block4a_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn  │ (None, 19, 19,    │        320 │ block4a_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_conv │ (None, 19, 19,    │     38,400 │ block4a_project_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn   │ (None, 19, 19,    │      1,920 │ block4b_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 19, 19,    │          0 │ block4b_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv      │ (None, 19, 19,    │      4,320 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn          │ (None, 19, 19,    │      1,920 │ block4b_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation  │ (None, 19, 19,    │          0 │ block4b_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze  │ (None, 480)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape  │ (None, 1, 1, 480) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand   │ (None, 1, 1, 480) │     10,080 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite   │ (None, 19, 19,    │          0 │ block4b_activati… │
# │ (Multiply)          │ 480)              │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_co… │ (None, 19, 19,    │     38,400 │ block4b_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_bn  │ (None, 19, 19,    │        320 │ block4b_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_drop        │ (None, 19, 19,    │          0 │ block4b_project_… │
# │ (Dropout)           │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_add (Add)   │ (None, 19, 19,    │          0 │ block4b_drop[0][… │
# │                     │ 80)               │            │ block4a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_conv │ (None, 19, 19,    │     38,400 │ block4b_add[0][0] │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_bn   │ (None, 19, 19,    │      1,920 │ block4c_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_act… │ (None, 19, 19,    │          0 │ block4c_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_dwconv      │ (None, 19, 19,    │      4,320 │ block4c_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_bn          │ (None, 19, 19,    │      1,920 │ block4c_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_activation  │ (None, 19, 19,    │          0 │ block4c_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_squeeze  │ (None, 480)       │          0 │ block4c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reshape  │ (None, 1, 1, 480) │          0 │ block4c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block4c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_expand   │ (None, 1, 1, 480) │     10,080 │ block4c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_excite   │ (None, 19, 19,    │          0 │ block4c_activati… │
# │ (Multiply)          │ 480)              │            │ block4c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_co… │ (None, 19, 19,    │     38,400 │ block4c_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_bn  │ (None, 19, 19,    │        320 │ block4c_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_drop        │ (None, 19, 19,    │          0 │ block4c_project_… │
# │ (Dropout)           │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_add (Add)   │ (None, 19, 19,    │          0 │ block4c_drop[0][… │
# │                     │ 80)               │            │ block4b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_conv │ (None, 19, 19,    │     38,400 │ block4c_add[0][0] │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_bn   │ (None, 19, 19,    │      1,920 │ block5a_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_act… │ (None, 19, 19,    │          0 │ block5a_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_dwconv      │ (None, 19, 19,    │     12,000 │ block5a_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_bn          │ (None, 19, 19,    │      1,920 │ block5a_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_activation  │ (None, 19, 19,    │          0 │ block5a_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_squeeze  │ (None, 480)       │          0 │ block5a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reshape  │ (None, 1, 1, 480) │          0 │ block5a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block5a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_expand   │ (None, 1, 1, 480) │     10,080 │ block5a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_excite   │ (None, 19, 19,    │          0 │ block5a_activati… │
# │ (Multiply)          │ 480)              │            │ block5a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_co… │ (None, 19, 19,    │     53,760 │ block5a_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_bn  │ (None, 19, 19,    │        448 │ block5a_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_conv │ (None, 19, 19,    │     75,264 │ block5a_project_… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_bn   │ (None, 19, 19,    │      2,688 │ block5b_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_act… │ (None, 19, 19,    │          0 │ block5b_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_dwconv      │ (None, 19, 19,    │     16,800 │ block5b_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_bn          │ (None, 19, 19,    │      2,688 │ block5b_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_activation  │ (None, 19, 19,    │          0 │ block5b_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_squeeze  │ (None, 672)       │          0 │ block5b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reshape  │ (None, 1, 1, 672) │          0 │ block5b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_excite   │ (None, 19, 19,    │          0 │ block5b_activati… │
# │ (Multiply)          │ 672)              │            │ block5b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_co… │ (None, 19, 19,    │     75,264 │ block5b_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_bn  │ (None, 19, 19,    │        448 │ block5b_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_drop        │ (None, 19, 19,    │          0 │ block5b_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_add (Add)   │ (None, 19, 19,    │          0 │ block5b_drop[0][… │
# │                     │ 112)              │            │ block5a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_conv │ (None, 19, 19,    │     75,264 │ block5b_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_bn   │ (None, 19, 19,    │      2,688 │ block5c_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_act… │ (None, 19, 19,    │          0 │ block5c_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_dwconv      │ (None, 19, 19,    │     16,800 │ block5c_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_bn          │ (None, 19, 19,    │      2,688 │ block5c_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_activation  │ (None, 19, 19,    │          0 │ block5c_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_squeeze  │ (None, 672)       │          0 │ block5c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reshape  │ (None, 1, 1, 672) │          0 │ block5c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_excite   │ (None, 19, 19,    │          0 │ block5c_activati… │
# │ (Multiply)          │ 672)              │            │ block5c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_co… │ (None, 19, 19,    │     75,264 │ block5c_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_bn  │ (None, 19, 19,    │        448 │ block5c_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_drop        │ (None, 19, 19,    │          0 │ block5c_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_add (Add)   │ (None, 19, 19,    │          0 │ block5c_drop[0][… │
# │                     │ 112)              │            │ block5b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_conv │ (None, 19, 19,    │     75,264 │ block5c_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_bn   │ (None, 19, 19,    │      2,688 │ block6a_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_act… │ (None, 19, 19,    │          0 │ block6a_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv_pad  │ (None, 23, 23,    │          0 │ block6a_expand_a… │
# │ (ZeroPadding2D)     │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv      │ (None, 10, 10,    │     16,800 │ block6a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_bn          │ (None, 10, 10,    │      2,688 │ block6a_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_activation  │ (None, 10, 10,    │          0 │ block6a_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_squeeze  │ (None, 672)       │          0 │ block6a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reshape  │ (None, 1, 1, 672) │          0 │ block6a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block6a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_expand   │ (None, 1, 1, 672) │     19,488 │ block6a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_excite   │ (None, 10, 10,    │          0 │ block6a_activati… │
# │ (Multiply)          │ 672)              │            │ block6a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_co… │ (None, 10, 10,    │    129,024 │ block6a_se_excit… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_bn  │ (None, 10, 10,    │        768 │ block6a_project_… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_conv │ (None, 10, 10,    │    221,184 │ block6a_project_… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_bn   │ (None, 10, 10,    │      4,608 │ block6b_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_act… │ (None, 10, 10,    │          0 │ block6b_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_dwconv      │ (None, 10, 10,    │     28,800 │ block6b_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_bn          │ (None, 10, 10,    │      4,608 │ block6b_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_activation  │ (None, 10, 10,    │          0 │ block6b_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_squeeze  │ (None, 1152)      │          0 │ block6b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reshape  │ (None, 1, 1,      │          0 │ block6b_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_expand   │ (None, 1, 1,      │     56,448 │ block6b_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_excite   │ (None, 10, 10,    │          0 │ block6b_activati… │
# │ (Multiply)          │ 1152)             │            │ block6b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_co… │ (None, 10, 10,    │    221,184 │ block6b_se_excit… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_bn  │ (None, 10, 10,    │        768 │ block6b_project_… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_drop        │ (None, 10, 10,    │          0 │ block6b_project_… │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_add (Add)   │ (None, 10, 10,    │          0 │ block6b_drop[0][… │
# │                     │ 192)              │            │ block6a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_conv │ (None, 10, 10,    │    221,184 │ block6b_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_bn   │ (None, 10, 10,    │      4,608 │ block6c_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_act… │ (None, 10, 10,    │          0 │ block6c_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_dwconv      │ (None, 10, 10,    │     28,800 │ block6c_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_bn          │ (None, 10, 10,    │      4,608 │ block6c_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_activation  │ (None, 10, 10,    │          0 │ block6c_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_squeeze  │ (None, 1152)      │          0 │ block6c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reshape  │ (None, 1, 1,      │          0 │ block6c_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_expand   │ (None, 1, 1,      │     56,448 │ block6c_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_excite   │ (None, 10, 10,    │          0 │ block6c_activati… │
# │ (Multiply)          │ 1152)             │            │ block6c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_co… │ (None, 10, 10,    │    221,184 │ block6c_se_excit… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_bn  │ (None, 10, 10,    │        768 │ block6c_project_… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_drop        │ (None, 10, 10,    │          0 │ block6c_project_… │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_add (Add)   │ (None, 10, 10,    │          0 │ block6c_drop[0][… │
# │                     │ 192)              │            │ block6b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_conv │ (None, 10, 10,    │    221,184 │ block6c_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_bn   │ (None, 10, 10,    │      4,608 │ block6d_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_act… │ (None, 10, 10,    │          0 │ block6d_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_dwconv      │ (None, 10, 10,    │     28,800 │ block6d_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_bn          │ (None, 10, 10,    │      4,608 │ block6d_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_activation  │ (None, 10, 10,    │          0 │ block6d_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_squeeze  │ (None, 1152)      │          0 │ block6d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reshape  │ (None, 1, 1,      │          0 │ block6d_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_expand   │ (None, 1, 1,      │     56,448 │ block6d_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_excite   │ (None, 10, 10,    │          0 │ block6d_activati… │
# │ (Multiply)          │ 1152)             │            │ block6d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_co… │ (None, 10, 10,    │    221,184 │ block6d_se_excit… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_bn  │ (None, 10, 10,    │        768 │ block6d_project_… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_drop        │ (None, 10, 10,    │          0 │ block6d_project_… │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_add (Add)   │ (None, 10, 10,    │          0 │ block6d_drop[0][… │
# │                     │ 192)              │            │ block6c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_conv │ (None, 10, 10,    │    221,184 │ block6d_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_bn   │ (None, 10, 10,    │      4,608 │ block7a_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_act… │ (None, 10, 10,    │          0 │ block7a_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_dwconv      │ (None, 10, 10,    │     10,368 │ block7a_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_bn          │ (None, 10, 10,    │      4,608 │ block7a_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_activation  │ (None, 10, 10,    │          0 │ block7a_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_squeeze  │ (None, 1152)      │          0 │ block7a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reshape  │ (None, 1, 1,      │          0 │ block7a_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block7a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_expand   │ (None, 1, 1,      │     56,448 │ block7a_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_excite   │ (None, 10, 10,    │          0 │ block7a_activati… │
# │ (Multiply)          │ 1152)             │            │ block7a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_co… │ (None, 10, 10,    │    368,640 │ block7a_se_excit… │
# │ (Conv2D)            │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_bn  │ (None, 10, 10,    │      1,280 │ block7a_project_… │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 10, 10,    │    409,600 │ block7a_project_… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 10, 10,    │      5,120 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 10, 10,    │          0 │ top_bn[0][0]      │
# │ (Activation)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 1280)      │      5,120 │ global_average_p… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1280)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    163,968 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64)        │          0 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4)         │        260 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,227,943 (16.13 MB)
#  Trainable params: 1,671,588 (6.38 MB)
#  Non-trainable params: 2,556,355 (9.75 MB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %% [markdown]
# # Training

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

hist = model.fit(tr_gen,
                 epochs=1000,
                 validation_data=valid_gen,
                 shuffle= False,
                 callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744651533.010460  189768 service.cc:152] XLA service 0x7ece48014790 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1744651533.010471  189768 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4080, Compute Capability 8.9
# 2025-04-14 23:25:33.179132: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1744651534.081453  189768 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-04-14 23:25:35.202295: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 719.14MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-14 23:25:35.456105: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 790.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-14 23:25:35.515651: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 323.62MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-14 23:25:35.515672: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 323.62MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-14 23:25:35.515680: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 323.62MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-14 23:25:35.515689: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 323.62MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-14 23:25:35.515695: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 323.62MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-14 23:25:35.515702: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 323.62MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-14 23:25:35.515709: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 323.62MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-14 23:25:35.515715: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 323.62MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-14 23:25:36.588777: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-14 23:25:36.668051: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-14 23:25:36.746630: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-14 23:25:36.826345: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-14 23:25:36.905916: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-14 23:25:37.383246: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-14 23:25:37.462927: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-14 23:25:37.651550: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-14 23:25:37.731186: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-14 23:25:37.811812: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   1/179 ━━━━━━━━━━━━━━━━━━━━ 39:46 13s/step - accuracy: 0.1875 - loss: 5.1592 - precision: 0.1333 - recall: 0.0625
# I0000 00:00:1744651541.656066  189768 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.4665 - loss: 4.3950 - precision: 0.5160 - recall: 0.3003
# 2025-04-14 23:26:21.630898: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-14 23:26:21.711261: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-14 23:26:21.791002: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.4673 - loss: 4.3931 - precision: 0.5171 - recall: 0.3012
# 2025-04-14 23:26:29.347728: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2169', 8 bytes spill stores, 8 bytes spill loads
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 64s 282ms/step - accuracy: 0.4681 - loss: 4.3911 - precision: 0.5182 - recall: 0.3022 - val_accuracy: 0.7939 - val_loss: 3.6339 - val_precision: 0.9055 - val_recall: 0.6733
# Epoch 2/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.8080 - loss: 3.4902 - precision: 0.8655 - recall: 0.7202 - val_accuracy: 0.8351 - val_loss: 3.2049 - val_precision: 0.8681 - val_recall: 0.7939
# Epoch 3/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.8471 - loss: 3.1408 - precision: 0.8846 - recall: 0.7895 - val_accuracy: 0.8565 - val_loss: 2.8872 - val_precision: 0.8748 - val_recall: 0.8321
# Epoch 4/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.8711 - loss: 2.8258 - precision: 0.9002 - recall: 0.8320 - val_accuracy: 0.8672 - val_loss: 2.5930 - val_precision: 0.8863 - val_recall: 0.8565
# Epoch 5/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.8961 - loss: 2.5098 - precision: 0.9198 - recall: 0.8659 - val_accuracy: 0.8855 - val_loss: 2.3060 - val_precision: 0.8951 - val_recall: 0.8733
# Epoch 6/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9078 - loss: 2.2368 - precision: 0.9286 - recall: 0.8815 - val_accuracy: 0.9145 - val_loss: 2.0280 - val_precision: 0.9276 - val_recall: 0.8992
# Epoch 7/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9221 - loss: 2.0041 - precision: 0.9347 - recall: 0.9034 - val_accuracy: 0.9176 - val_loss: 1.8099 - val_precision: 0.9308 - val_recall: 0.9038
# Epoch 8/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9278 - loss: 1.7793 - precision: 0.9381 - recall: 0.9132 - val_accuracy: 0.9359 - val_loss: 1.5931 - val_precision: 0.9498 - val_recall: 0.9237
# Epoch 9/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9378 - loss: 1.5718 - precision: 0.9500 - recall: 0.9277 - val_accuracy: 0.9420 - val_loss: 1.4155 - val_precision: 0.9486 - val_recall: 0.9298
# Epoch 10/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9483 - loss: 1.3857 - precision: 0.9554 - recall: 0.9374 - val_accuracy: 0.9405 - val_loss: 1.2691 - val_precision: 0.9516 - val_recall: 0.9298
# Epoch 11/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9527 - loss: 1.2292 - precision: 0.9622 - recall: 0.9461 - val_accuracy: 0.9496 - val_loss: 1.1194 - val_precision: 0.9537 - val_recall: 0.9435
# Epoch 12/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9582 - loss: 1.1003 - precision: 0.9656 - recall: 0.9518 - val_accuracy: 0.9618 - val_loss: 0.9785 - val_precision: 0.9630 - val_recall: 0.9527
# Epoch 13/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9524 - loss: 0.9895 - precision: 0.9606 - recall: 0.9467 - val_accuracy: 0.9664 - val_loss: 0.8679 - val_precision: 0.9677 - val_recall: 0.9603
# Epoch 14/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9669 - loss: 0.8682 - precision: 0.9701 - recall: 0.9611 - val_accuracy: 0.9710 - val_loss: 0.7746 - val_precision: 0.9754 - val_recall: 0.9695
# Epoch 15/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9670 - loss: 0.7731 - precision: 0.9713 - recall: 0.9627 - val_accuracy: 0.9710 - val_loss: 0.6951 - val_precision: 0.9709 - val_recall: 0.9695
# Epoch 16/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9656 - loss: 0.7023 - precision: 0.9699 - recall: 0.9613 - val_accuracy: 0.9664 - val_loss: 0.6390 - val_precision: 0.9664 - val_recall: 0.9649
# Epoch 17/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9687 - loss: 0.6252 - precision: 0.9726 - recall: 0.9616 - val_accuracy: 0.9832 - val_loss: 0.5590 - val_precision: 0.9832 - val_recall: 0.9817
# Epoch 18/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9712 - loss: 0.5710 - precision: 0.9741 - recall: 0.9669 - val_accuracy: 0.9786 - val_loss: 0.5162 - val_precision: 0.9786 - val_recall: 0.9786
# Epoch 19/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9758 - loss: 0.5068 - precision: 0.9775 - recall: 0.9722 - val_accuracy: 0.9817 - val_loss: 0.4630 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 20/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9746 - loss: 0.4709 - precision: 0.9778 - recall: 0.9722 - val_accuracy: 0.9802 - val_loss: 0.4155 - val_precision: 0.9816 - val_recall: 0.9786
# Epoch 21/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9812 - loss: 0.4220 - precision: 0.9826 - recall: 0.9784 - val_accuracy: 0.9863 - val_loss: 0.3808 - val_precision: 0.9878 - val_recall: 0.9863
# Epoch 22/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9813 - loss: 0.3862 - precision: 0.9829 - recall: 0.9793 - val_accuracy: 0.9802 - val_loss: 0.3548 - val_precision: 0.9832 - val_recall: 0.9802
# Epoch 23/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9676 - loss: 0.3786 - precision: 0.9722 - recall: 0.9666 - val_accuracy: 0.9817 - val_loss: 0.3263 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 24/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9824 - loss: 0.3259 - precision: 0.9841 - recall: 0.9801 - val_accuracy: 0.9817 - val_loss: 0.3002 - val_precision: 0.9832 - val_recall: 0.9817
# Epoch 25/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9826 - loss: 0.2988 - precision: 0.9843 - recall: 0.9809 - val_accuracy: 0.9847 - val_loss: 0.2772 - val_precision: 0.9847 - val_recall: 0.9847
# Epoch 26/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9822 - loss: 0.2847 - precision: 0.9839 - recall: 0.9787 - val_accuracy: 0.9832 - val_loss: 0.2658 - val_precision: 0.9847 - val_recall: 0.9832
# Epoch 27/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9877 - loss: 0.2530 - precision: 0.9891 - recall: 0.9863 - val_accuracy: 0.9847 - val_loss: 0.2380 - val_precision: 0.9847 - val_recall: 0.9847
# Epoch 28/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9825 - loss: 0.2548 - precision: 0.9845 - recall: 0.9815 - val_accuracy: 0.9878 - val_loss: 0.2260 - val_precision: 0.9878 - val_recall: 0.9878
# Epoch 29/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9787 - loss: 0.2481 - precision: 0.9794 - recall: 0.9766 - val_accuracy: 0.9893 - val_loss: 0.2113 - val_precision: 0.9893 - val_recall: 0.9893
# Epoch 30/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9875 - loss: 0.2133 - precision: 0.9880 - recall: 0.9852 - val_accuracy: 0.9863 - val_loss: 0.2055 - val_precision: 0.9863 - val_recall: 0.9863
# Epoch 31/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9829 - loss: 0.2141 - precision: 0.9839 - recall: 0.9808 - val_accuracy: 0.9863 - val_loss: 0.1921 - val_precision: 0.9878 - val_recall: 0.9863
# Epoch 32/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9911 - loss: 0.1831 - precision: 0.9917 - recall: 0.9906 - val_accuracy: 0.9893 - val_loss: 0.1840 - val_precision: 0.9893 - val_recall: 0.9878
# Epoch 33/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9878 - loss: 0.1791 - precision: 0.9884 - recall: 0.9866 - val_accuracy: 0.9802 - val_loss: 0.1900 - val_precision: 0.9817 - val_recall: 0.9802
# Epoch 34/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9827 - loss: 0.1765 - precision: 0.9827 - recall: 0.9809 - val_accuracy: 0.9893 - val_loss: 0.1630 - val_precision: 0.9893 - val_recall: 0.9893
# Epoch 35/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9845 - loss: 0.1731 - precision: 0.9856 - recall: 0.9840 - val_accuracy: 0.9924 - val_loss: 0.1494 - val_precision: 0.9924 - val_recall: 0.9924
# Epoch 36/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9834 - loss: 0.1594 - precision: 0.9852 - recall: 0.9834 - val_accuracy: 0.9893 - val_loss: 0.1404 - val_precision: 0.9908 - val_recall: 0.9893
# Epoch 37/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9880 - loss: 0.1525 - precision: 0.9886 - recall: 0.9875 - val_accuracy: 0.9939 - val_loss: 0.1342 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 38/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9907 - loss: 0.1316 - precision: 0.9914 - recall: 0.9904 - val_accuracy: 0.9893 - val_loss: 0.1331 - val_precision: 0.9908 - val_recall: 0.9893
# Epoch 39/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9854 - loss: 0.1445 - precision: 0.9860 - recall: 0.9851 - val_accuracy: 0.9908 - val_loss: 0.1268 - val_precision: 0.9908 - val_recall: 0.9893
# Epoch 40/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9873 - loss: 0.1356 - precision: 0.9888 - recall: 0.9863 - val_accuracy: 0.9924 - val_loss: 0.1176 - val_precision: 0.9924 - val_recall: 0.9924
# Epoch 41/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9883 - loss: 0.1253 - precision: 0.9889 - recall: 0.9873 - val_accuracy: 0.9893 - val_loss: 0.1164 - val_precision: 0.9939 - val_recall: 0.9893
# Epoch 42/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9875 - loss: 0.1247 - precision: 0.9891 - recall: 0.9873 - val_accuracy: 0.9924 - val_loss: 0.1087 - val_precision: 0.9939 - val_recall: 0.9924
# Epoch 43/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9925 - loss: 0.1111 - precision: 0.9940 - recall: 0.9901 - val_accuracy: 0.9893 - val_loss: 0.1104 - val_precision: 0.9893 - val_recall: 0.9878
# Epoch 44/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9874 - loss: 0.1183 - precision: 0.9884 - recall: 0.9861 - val_accuracy: 0.9908 - val_loss: 0.1106 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 45/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9901 - loss: 0.1083 - precision: 0.9912 - recall: 0.9894 - val_accuracy: 0.9924 - val_loss: 0.1058 - val_precision: 0.9924 - val_recall: 0.9908
# Epoch 46/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9931 - loss: 0.0981 - precision: 0.9938 - recall: 0.9931 - val_accuracy: 0.9893 - val_loss: 0.1012 - val_precision: 0.9893 - val_recall: 0.9893
# Epoch 47/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9931 - loss: 0.0926 - precision: 0.9943 - recall: 0.9924 - val_accuracy: 0.9908 - val_loss: 0.0994 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 48/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9873 - loss: 0.1024 - precision: 0.9880 - recall: 0.9867 - val_accuracy: 0.9893 - val_loss: 0.1013 - val_precision: 0.9893 - val_recall: 0.9893
# Epoch 49/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9885 - loss: 0.0979 - precision: 0.9892 - recall: 0.9881 - val_accuracy: 0.9878 - val_loss: 0.0944 - val_precision: 0.9878 - val_recall: 0.9878
# Epoch 50/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9896 - loss: 0.0957 - precision: 0.9912 - recall: 0.9889 - val_accuracy: 0.9908 - val_loss: 0.0940 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 51/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9883 - loss: 0.0951 - precision: 0.9899 - recall: 0.9878 - val_accuracy: 0.9893 - val_loss: 0.0930 - val_precision: 0.9893 - val_recall: 0.9893
# Epoch 52/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9915 - loss: 0.0906 - precision: 0.9918 - recall: 0.9915 - val_accuracy: 0.9908 - val_loss: 0.0893 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 53/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9902 - loss: 0.0913 - precision: 0.9907 - recall: 0.9891 - val_accuracy: 0.9893 - val_loss: 0.0910 - val_precision: 0.9893 - val_recall: 0.9893
# Epoch 54/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9920 - loss: 0.0902 - precision: 0.9925 - recall: 0.9910 - val_accuracy: 0.9878 - val_loss: 0.0869 - val_precision: 0.9908 - val_recall: 0.9863
# Epoch 55/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9929 - loss: 0.0728 - precision: 0.9934 - recall: 0.9922 - val_accuracy: 0.9878 - val_loss: 0.0879 - val_precision: 0.9878 - val_recall: 0.9878
# Epoch 56/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.9938 - loss: 0.0706 - precision: 0.9938 - recall: 0.9938 - val_accuracy: 0.9939 - val_loss: 0.0781 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 57/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9886 - loss: 0.0807 - precision: 0.9891 - recall: 0.9886 - val_accuracy: 0.9908 - val_loss: 0.0795 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 58/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9921 - loss: 0.0741 - precision: 0.9929 - recall: 0.9920 - val_accuracy: 0.9924 - val_loss: 0.0772 - val_precision: 0.9939 - val_recall: 0.9924
# Epoch 59/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9939 - loss: 0.0693 - precision: 0.9947 - recall: 0.9935 - val_accuracy: 0.9893 - val_loss: 0.0808 - val_precision: 0.9893 - val_recall: 0.9893
# Epoch 60/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9955 - loss: 0.0628 - precision: 0.9956 - recall: 0.9954 - val_accuracy: 0.9893 - val_loss: 0.0843 - val_precision: 0.9893 - val_recall: 0.9878
# Epoch 61/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9943 - loss: 0.0651 - precision: 0.9943 - recall: 0.9937 - val_accuracy: 0.9893 - val_loss: 0.0763 - val_precision: 0.9893 - val_recall: 0.9893
# Epoch 62/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9946 - loss: 0.0633 - precision: 0.9946 - recall: 0.9942 - val_accuracy: 0.9924 - val_loss: 0.0737 - val_precision: 0.9924 - val_recall: 0.9924
# Epoch 63/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9944 - loss: 0.0590 - precision: 0.9960 - recall: 0.9943 - val_accuracy: 0.9908 - val_loss: 0.0710 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 64/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9915 - loss: 0.0670 - precision: 0.9925 - recall: 0.9909 - val_accuracy: 0.9908 - val_loss: 0.0724 - val_precision: 0.9908 - val_recall: 0.9893
# Epoch 65/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9932 - loss: 0.0630 - precision: 0.9938 - recall: 0.9932 - val_accuracy: 0.9924 - val_loss: 0.0678 - val_precision: 0.9924 - val_recall: 0.9924
# Epoch 66/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9937 - loss: 0.0615 - precision: 0.9938 - recall: 0.9935 - val_accuracy: 0.9924 - val_loss: 0.0660 - val_precision: 0.9924 - val_recall: 0.9924
# Epoch 67/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9933 - loss: 0.0605 - precision: 0.9942 - recall: 0.9933 - val_accuracy: 0.9924 - val_loss: 0.0657 - val_precision: 0.9924 - val_recall: 0.9924
# Epoch 68/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9896 - loss: 0.0674 - precision: 0.9898 - recall: 0.9895 - val_accuracy: 0.9893 - val_loss: 0.0698 - val_precision: 0.9893 - val_recall: 0.9893
# Epoch 69/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9913 - loss: 0.0607 - precision: 0.9914 - recall: 0.9913 - val_accuracy: 0.9908 - val_loss: 0.0682 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 70/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9935 - loss: 0.0549 - precision: 0.9937 - recall: 0.9928 - val_accuracy: 0.9924 - val_loss: 0.0661 - val_precision: 0.9924 - val_recall: 0.9924
# Epoch 71/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9948 - loss: 0.0564 - precision: 0.9953 - recall: 0.9945 - val_accuracy: 0.9924 - val_loss: 0.0652 - val_precision: 0.9924 - val_recall: 0.9924
# Epoch 72/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9950 - loss: 0.0507 - precision: 0.9958 - recall: 0.9944 - val_accuracy: 0.9939 - val_loss: 0.0585 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 73/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9963 - loss: 0.0475 - precision: 0.9966 - recall: 0.9963 - val_accuracy: 0.9939 - val_loss: 0.0579 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 74/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9940 - loss: 0.0591 - precision: 0.9945 - recall: 0.9940 - val_accuracy: 0.9924 - val_loss: 0.0621 - val_precision: 0.9939 - val_recall: 0.9924
# Epoch 75/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9959 - loss: 0.0498 - precision: 0.9964 - recall: 0.9956 - val_accuracy: 0.9939 - val_loss: 0.0583 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 76/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9953 - loss: 0.0471 - precision: 0.9957 - recall: 0.9953 - val_accuracy: 0.9939 - val_loss: 0.0596 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 77/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 210ms/step - accuracy: 0.9959 - loss: 0.0486 - precision: 0.9959 - recall: 0.9953 - val_accuracy: 0.9939 - val_loss: 0.0616 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 78/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9955 - loss: 0.0462 - precision: 0.9955 - recall: 0.9954 - val_accuracy: 0.9939 - val_loss: 0.0586 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 79/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9943 - loss: 0.0489 - precision: 0.9948 - recall: 0.9938 - val_accuracy: 0.9954 - val_loss: 0.0540 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 80/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9955 - loss: 0.0485 - precision: 0.9960 - recall: 0.9947 - val_accuracy: 0.9939 - val_loss: 0.0558 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 81/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9956 - loss: 0.0482 - precision: 0.9958 - recall: 0.9949 - val_accuracy: 0.9939 - val_loss: 0.0615 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 82/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9939 - loss: 0.0454 - precision: 0.9949 - recall: 0.9939 - val_accuracy: 0.9939 - val_loss: 0.0590 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 83/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9965 - loss: 0.0407 - precision: 0.9967 - recall: 0.9964 - val_accuracy: 0.9939 - val_loss: 0.0625 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 84/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9945 - loss: 0.0432 - precision: 0.9948 - recall: 0.9939 - val_accuracy: 0.9939 - val_loss: 0.0581 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 85/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 210ms/step - accuracy: 0.9933 - loss: 0.0474 - precision: 0.9942 - recall: 0.9928 - val_accuracy: 0.9954 - val_loss: 0.0523 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 86/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9942 - loss: 0.0443 - precision: 0.9952 - recall: 0.9942 - val_accuracy: 0.9954 - val_loss: 0.0565 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 87/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9973 - loss: 0.0394 - precision: 0.9973 - recall: 0.9972 - val_accuracy: 0.9939 - val_loss: 0.0589 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 88/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9945 - loss: 0.0435 - precision: 0.9945 - recall: 0.9945 - val_accuracy: 0.9954 - val_loss: 0.0538 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 89/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.9946 - loss: 0.0434 - precision: 0.9951 - recall: 0.9945 - val_accuracy: 0.9939 - val_loss: 0.0526 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 90/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9955 - loss: 0.0421 - precision: 0.9957 - recall: 0.9955 - val_accuracy: 0.9954 - val_loss: 0.0525 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 91/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9970 - loss: 0.0393 - precision: 0.9970 - recall: 0.9964 - val_accuracy: 0.9939 - val_loss: 0.0544 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 92/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9963 - loss: 0.0389 - precision: 0.9963 - recall: 0.9961 - val_accuracy: 0.9939 - val_loss: 0.0537 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 93/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9976 - loss: 0.0377 - precision: 0.9976 - recall: 0.9976 - val_accuracy: 0.9924 - val_loss: 0.0555 - val_precision: 0.9939 - val_recall: 0.9924
# Epoch 94/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.9971 - loss: 0.0368 - precision: 0.9971 - recall: 0.9965 - val_accuracy: 0.9954 - val_loss: 0.0498 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 95/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9938 - loss: 0.0401 - precision: 0.9940 - recall: 0.9938 - val_accuracy: 0.9939 - val_loss: 0.0477 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 96/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9946 - loss: 0.0450 - precision: 0.9946 - recall: 0.9946 - val_accuracy: 0.9939 - val_loss: 0.0482 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 97/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9965 - loss: 0.0361 - precision: 0.9965 - recall: 0.9955 - val_accuracy: 0.9939 - val_loss: 0.0492 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 98/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9958 - loss: 0.0418 - precision: 0.9959 - recall: 0.9949 - val_accuracy: 0.9939 - val_loss: 0.0447 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 99/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9956 - loss: 0.0363 - precision: 0.9967 - recall: 0.9956 - val_accuracy: 0.9939 - val_loss: 0.0509 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 100/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9964 - loss: 0.0345 - precision: 0.9968 - recall: 0.9964 - val_accuracy: 0.9939 - val_loss: 0.0550 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 101/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9950 - loss: 0.0417 - precision: 0.9956 - recall: 0.9948 - val_accuracy: 0.9939 - val_loss: 0.0544 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 102/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9954 - loss: 0.0392 - precision: 0.9955 - recall: 0.9954 - val_accuracy: 0.9939 - val_loss: 0.0519 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 103/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.9948 - loss: 0.0373 - precision: 0.9950 - recall: 0.9948 - val_accuracy: 0.9939 - val_loss: 0.0492 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 104/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9980 - loss: 0.0327 - precision: 0.9980 - recall: 0.9980 - val_accuracy: 0.9939 - val_loss: 0.0483 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 105/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 209ms/step - accuracy: 0.9940 - loss: 0.0398 - precision: 0.9954 - recall: 0.9940 - val_accuracy: 0.9939 - val_loss: 0.0508 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 106/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9952 - loss: 0.0344 - precision: 0.9967 - recall: 0.9951 - val_accuracy: 0.9939 - val_loss: 0.0518 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 107/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9959 - loss: 0.0339 - precision: 0.9959 - recall: 0.9959 - val_accuracy: 0.9939 - val_loss: 0.0462 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 108/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9974 - loss: 0.0321 - precision: 0.9974 - recall: 0.9974 - val_accuracy: 0.9939 - val_loss: 0.0490 - val_precision: 0.9939 - val_recall: 0.9939

# %% [markdown]
# # Visualize model performance

# %%
hist.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'precision', 'recall', 'val_accuracy', 'val_loss', 'val_precision', 'val_recall'])

# %%
tr_acc = hist.history['accuracy']
tr_loss = hist.history['loss']
tr_per = hist.history['precision']
tr_recall = hist.history['recall']
val_acc = hist.history['val_accuracy']
val_loss = hist.history['val_loss']
val_per = hist.history['val_precision']
val_recall = hist.history['val_recall']

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
index_precision = np.argmax(val_per)
per_highest = val_per[index_precision]
index_recall = np.argmax(val_recall)
recall_highest = val_recall[index_recall]

Epochs = [i + 1 for i in range(len(tr_acc))]
loss_label = f'Best epoch = {str(index_loss + 1)}'
acc_label = f'Best epoch = {str(index_acc + 1)}'
per_label = f'Best epoch = {str(index_precision + 1)}'
recall_label = f'Best epoch = {str(index_recall + 1)}'


plt.figure(figsize=(20, 12))
plt.style.use('fivethirtyeight')


plt.subplot(2, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label='Training loss')
plt.plot(Epochs, val_loss, 'g', label='Validation loss')
plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label='Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy')
plt.scatter(index_acc + 1, acc_highest, s=150, c='blue', label=acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(Epochs, tr_per, 'r', label='Precision')
plt.plot(Epochs, val_per, 'g', label='Validation Precision')
plt.scatter(index_precision + 1, per_highest, s=150, c='blue', label=per_label)
plt.title('Precision and Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(Epochs, tr_recall, 'r', label='Recall')
plt.plot(Epochs, val_recall, 'g', label='Validation Recall')
plt.scatter(index_recall + 1, recall_highest, s=150, c='blue', label=recall_label)
plt.title('Recall and Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.grid(True)

plt.suptitle('Model Training Metrics Over Epochs', fontsize=16)
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
train_score = model.evaluate(tr_gen, verbose=1)
valid_score = model.evaluate(valid_gen, verbose=1)
test_score = model.evaluate(ts_gen, verbose=1)

print(f"Train Loss: {train_score[0]:.4f}")
print(f"Train Accuracy: {train_score[1]*100:.2f}%")
print('-' * 20)
print(f"Validation Loss: {valid_score[0]:.4f}")
print(f"Validation Accuracy: {valid_score[1]*100:.2f}%")
print('-' * 20)
print(f"Test Loss: {test_score[0]:.4f}")
print(f"Test Accuracy: {test_score[1]*100:.2f}%")

print(test_score)
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9999 - loss: 0.0236 - precision: 0.9999 - recall: 0.9999
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9954 - loss: 0.0410 - precision: 0.9954 - recall: 0.9954
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9957 - loss: 0.0341 - precision: 0.9957 - recall: 0.9957
# Train Loss: 0.0234
# Train Accuracy: 99.98%
# --------------------
# Validation Loss: 0.0447
# Validation Accuracy: 99.39%
# --------------------
# Test Loss: 0.0345
# Test Accuracy: 99.54%
# [0.034535717219114304, 0.9954268336296082, 0.9954268336296082, 0.9954268336296082]

# %%
preds = model.predict(ts_gen)
y_pred = np.argmax(preds, axis=1)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step

# %% [markdown]
# # Confusion matrix

# %%
cm = confusion_matrix(ts_gen.classes, y_pred)
labels = list(class_dict.keys())
plt.figure(figsize=(8,7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('Truth Label')
plt.show()

# %% [markdown]
# # Classification report

# %%
report = classification_report(ts_gen.classes, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       150
#            1       0.99      0.99      0.99       153
#            2       1.00      1.00      1.00       203
#            3       1.00      1.00      1.00       150
#
#     accuracy                           1.00       656
#    macro avg       1.00      1.00      1.00       656
# weighted avg       1.00      1.00      1.00       656

# %% [markdown]
# # Testing

# %%
def predict(img_path):
    import numpy as np
    import matplotlib.pyplot as plt
    from PIL import Image
    from tensorflow.keras.applications.efficientnet import preprocess_input

    # Generator label order
    labels = list(tr_gen.class_indices.keys())

    plt.figure(figsize=(12, 12))
    img = Image.open(img_path).convert('RGB')
    resized_img = img.resize((300, 300))
    img = np.asarray(resized_img)
    img = np.expand_dims(img, axis=0)

    img = preprocess_input(img)

    predictions = model.predict(img)
    probs = list(predictions[0])

    # Plotting
    plt.subplot(2, 1, 1)
    plt.imshow(resized_img)
    plt.axis('off')
    plt.title("Input Image")

    plt.subplot(2, 1, 2)
    bars = plt.barh(labels, probs, color='skyblue')
    plt.xlabel('Probability', fontsize=15)
    plt.title("Class Probabilities")
    ax = plt.gca()
    ax.bar_label(bars, fmt='%.2f')
    plt.tight_layout()
    plt.show()

# %%
predict('/home/readinggroup/Desktop/K_venv/dl/MRI/Testing/notumor/Te-noTr_0000.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
predict('/home/readinggroup/Desktop/K_venv/dl/MRI/Testing/glioma/Te-glTr_0000.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
predict('/home/readinggroup/Desktop/K_venv/dl/MRI/Testing/pituitary/Te-piTr_0008.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
