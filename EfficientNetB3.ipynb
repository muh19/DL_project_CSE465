# %%
import os
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
#---------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
#---------------------------------------
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
#---------------------------------------
import logging
import warnings
logging.getLogger().setLevel(logging.ERROR)
warnings.filterwarnings("ignore")
warnings.simplefilter('ignore')
# Out:
# 2025-04-15 10:06:39.652802: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-15 10:06:39.660068: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744689999.668423  254933 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744689999.671028  254933 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1744689999.677582  254933 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744689999.677590  254933 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744689999.677591  254933 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744689999.677592  254933 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-15 10:06:39.679775: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Load Training Data

# %%
def train_df(tr_path):
    classes, class_paths = zip(*[(label, os.path.join(tr_path, label, image))
                                 for label in os.listdir(tr_path) if os.path.isdir(os.path.join(tr_path, label))
                                 for image in os.listdir(os.path.join(tr_path, label))])

    tr_df = pd.DataFrame({'Class Path': class_paths, 'Class': classes})
    return tr_df

# %%
tr_df = train_df('/home/readinggroup/Desktop/K_venv/dl/MRI/Training')
tr_df
# Out:
#                                              Class Path       Class
# 0     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# 1     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# 2     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# 3     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# 4     /home/readinggroup/Desktop/K_venv/dl/MRI/Train...  meningioma
# ...                                                 ...         ...
# 5707  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
# 5708  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
# 5709  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
# 5710  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
# 5711  /home/readinggroup/Desktop/K_venv/dl/MRI/Train...      glioma
#
# [5712 rows x 2 columns]

# %% [markdown]
# # Load Test Data

# %%
def test_df(ts_path):
    classes, class_paths = zip(*[(label, os.path.join(ts_path, label, image))
                                 for label in os.listdir(ts_path) if os.path.isdir(os.path.join(ts_path, label))
                                 for image in os.listdir(os.path.join(ts_path, label))])

    ts_df = pd.DataFrame({'Class Path': class_paths, 'Class': classes})
    return ts_df

# %%
ts_df = test_df('/home/readinggroup/Desktop/K_venv/dl/MRI/Testing')
ts_df
# Out:
#                                              Class Path       Class
# 0     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 1     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 2     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 3     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 4     /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# ...                                                 ...         ...
# 1306  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 1307  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 1308  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 1309  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 1310  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
#
# [1311 rows x 2 columns]

# %% [markdown]
# # Number of images in each class in train data

# %%
plt.figure(figsize=(15,7))
ax = sns.countplot(data=tr_df , y=tr_df['Class'])

plt.xlabel('')
plt.ylabel('')
plt.title('Count of images in each class', fontsize=20)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# # Count each class in test data

# %%
plt.figure(figsize=(15,7))
ax = sns.countplot(data=ts_df , y=ts_df['Class'])

plt.xlabel('')
plt.ylabel('')
plt.title('Count of images in each class', fontsize=20)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# # Splitting dataset

# %%
valid_df, ts_df = train_test_split(ts_df, train_size=0.5, random_state=20, stratify=ts_df['Class'])
valid_df
# Out:
#                                              Class Path       Class
# 1297  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 18    /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 367   /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...   pituitary
# 73    /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 1120  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# ...                                                 ...         ...
# 1070  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 860   /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...     notumor
# 1284  /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...      glioma
# 194   /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...  meningioma
# 932   /home/readinggroup/Desktop/K_venv/dl/MRI/Testi...     notumor
#
# [655 rows x 2 columns]

# %% [markdown]
# # Data preprocessing

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input  # For B3

batch_size = 32
img_size = (300, 300)
seed = 42

# Augmentation for training
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.15,
    zoom_range=0.1,
    horizontal_flip=True,
    brightness_range=(0.8, 1.2),
    fill_mode='nearest'
)

# No augmentation for validation and test
test_val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# Train generator
tr_gen = train_datagen.flow_from_dataframe(
    dataframe=tr_df,
    x_col='Class Path',
    y_col='Class',
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb',
    seed=seed
)

# Validation generator
valid_gen = test_val_datagen.flow_from_dataframe(
    dataframe=valid_df,
    x_col='Class Path',
    y_col='Class',
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=False,
    seed=seed
)

# Test generator
ts_gen = test_val_datagen.flow_from_dataframe(
    dataframe=ts_df,
    x_col='Class Path',
    y_col='Class',
    target_size=img_size,
    batch_size=16,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=False,
    seed=seed
)

print("Class indices:", tr_gen.class_indices)
# Out:
# Found 5712 validated image filenames belonging to 4 classes.
# Found 655 validated image filenames belonging to 4 classes.
# Found 656 validated image filenames belonging to 4 classes.
# Class indices: {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}

# %% [markdown]
# # Getting samples from data

# %%
class_dict = tr_gen.class_indices
classes = list(class_dict.keys())
images, labels = next(ts_gen)

plt.figure(figsize=(20, 20))

for i, (image, label) in enumerate(zip(images, labels)):
    plt.subplot(4, 4, i + 1)

    image_vis = (image + 1.0) / 2.0
    image_vis = np.clip(image_vis, 0, 1)

    plt.imshow(image_vis)
    class_name = classes[np.argmax(label)]
    plt.title(class_name, color='k', fontsize=15)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Building the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, BatchNormalization, Dropout, Dense
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.optimizers.schedules import ExponentialDecay

# Image shape for EfficientNetB3
img_shape = (300, 300, 3)

# Load EfficientNetB3 as base model
base_model = tf.keras.applications.EfficientNetB3(
    weights='imagenet',
    include_top=False,
    input_shape=img_shape
)

# Fine-tune: freeze only early layers
base_model.trainable = True
for layer in base_model.layers[:200]:
    layer.trainable = False

# Define the model
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    BatchNormalization(),
    Dropout(0.3),
    Dense(160, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    Dropout(0.25),
    Dense(4, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2(0.01))
])

# Learning rate schedule
lr_schedule = ExponentialDecay(
    initial_learning_rate=1e-4,
    decay_steps=1000,
    decay_rate=0.9
)

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='categorical_crossentropy',
    metrics=['accuracy', Precision(), Recall()]
)

model.summary()
# Out:
# I0000 00:00:1744690001.244391  254933 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13880 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb3 (Functional)     │ (None, 10, 10, 1536)   │    10,783,535 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1536)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1536)           │         6,144 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1536)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 160)            │       245,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           644 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,036,243 (42.10 MB)
#  Trainable params: 10,071,474 (38.42 MB)
#  Non-trainable params: 964,769 (3.68 MB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %% [markdown]
# # Training

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

hist = model.fit(tr_gen,
                 epochs=1000,
                 validation_data=valid_gen,
                 shuffle= False,
                 callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744690014.274322  255081 service.cc:152] XLA service 0x7c2240001740 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1744690014.274335  255081 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4080, Compute Capability 8.9
# 2025-04-15 10:06:54.692368: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1744690016.722146  255081 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-04-15 10:07:01.131519: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:01.211979: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:02.092486: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:02.173457: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:02.494201: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:02.575099: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:02.816044: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:02.897677: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:03.078611: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:03.160177: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:03.345873: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:03.433448: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   2/179 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - accuracy: 0.1641 - loss: 5.8617 - precision: 0.1339 - recall: 0.1172
# I0000 00:00:1744690031.273179  255081 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.6853 - loss: 3.8330 - precision: 0.7063 - recall: 0.6565
# 2025-04-15 10:07:53.875126: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:53.955996: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:54.240720: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:54.321366: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:54.402488: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:54.629266: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-04-15 10:07:54.711328: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 88s 334ms/step - accuracy: 0.6867 - loss: 3.8284 - precision: 0.7076 - recall: 0.6580 - val_accuracy: 0.9099 - val_loss: 2.9924 - val_precision: 0.9223 - val_recall: 0.8885
# Epoch 2/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9329 - loss: 2.8893 - precision: 0.9381 - recall: 0.9279 - val_accuracy: 0.9573 - val_loss: 2.5909 - val_precision: 0.9615 - val_recall: 0.9542
# Epoch 3/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.9509 - loss: 2.5512 - precision: 0.9533 - recall: 0.9484 - val_accuracy: 0.9832 - val_loss: 2.2634 - val_precision: 0.9832 - val_recall: 0.9817
# Epoch 4/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9716 - loss: 2.2357 - precision: 0.9730 - recall: 0.9684 - val_accuracy: 0.9863 - val_loss: 1.9844 - val_precision: 0.9863 - val_recall: 0.9863
# Epoch 5/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9814 - loss: 1.9430 - precision: 0.9835 - recall: 0.9803 - val_accuracy: 0.9878 - val_loss: 1.7365 - val_precision: 0.9893 - val_recall: 0.9878
# Epoch 6/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9822 - loss: 1.6970 - precision: 0.9831 - recall: 0.9815 - val_accuracy: 0.9893 - val_loss: 1.4969 - val_precision: 0.9893 - val_recall: 0.9893
# Epoch 7/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9900 - loss: 1.4541 - precision: 0.9907 - recall: 0.9890 - val_accuracy: 0.9924 - val_loss: 1.2915 - val_precision: 0.9969 - val_recall: 0.9924
# Epoch 8/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9905 - loss: 1.2498 - precision: 0.9907 - recall: 0.9902 - val_accuracy: 0.9939 - val_loss: 1.1068 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 9/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9935 - loss: 1.0637 - precision: 0.9944 - recall: 0.9927 - val_accuracy: 0.9924 - val_loss: 0.9504 - val_precision: 0.9924 - val_recall: 0.9924
# Epoch 10/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9952 - loss: 0.9043 - precision: 0.9952 - recall: 0.9949 - val_accuracy: 0.9939 - val_loss: 0.8053 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 11/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9947 - loss: 0.7667 - precision: 0.9949 - recall: 0.9942 - val_accuracy: 0.9924 - val_loss: 0.6876 - val_precision: 0.9939 - val_recall: 0.9924
# Epoch 12/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9946 - loss: 0.6539 - precision: 0.9952 - recall: 0.9943 - val_accuracy: 0.9924 - val_loss: 0.5723 - val_precision: 0.9939 - val_recall: 0.9924
# Epoch 13/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9956 - loss: 0.5446 - precision: 0.9959 - recall: 0.9956 - val_accuracy: 0.9878 - val_loss: 0.4970 - val_precision: 0.9908 - val_recall: 0.9878
# Epoch 14/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9970 - loss: 0.4560 - precision: 0.9971 - recall: 0.9963 - val_accuracy: 0.9924 - val_loss: 0.4106 - val_precision: 0.9924 - val_recall: 0.9924
# Epoch 15/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9952 - loss: 0.3860 - precision: 0.9956 - recall: 0.9950 - val_accuracy: 0.9908 - val_loss: 0.3632 - val_precision: 0.9924 - val_recall: 0.9908
# Epoch 16/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9967 - loss: 0.3254 - precision: 0.9969 - recall: 0.9956 - val_accuracy: 0.9954 - val_loss: 0.2947 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 17/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9977 - loss: 0.2706 - precision: 0.9980 - recall: 0.9977 - val_accuracy: 0.9924 - val_loss: 0.2613 - val_precision: 0.9939 - val_recall: 0.9893
# Epoch 18/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9950 - loss: 0.2345 - precision: 0.9950 - recall: 0.9945 - val_accuracy: 0.9954 - val_loss: 0.2189 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 19/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9980 - loss: 0.1930 - precision: 0.9982 - recall: 0.9979 - val_accuracy: 0.9954 - val_loss: 0.1896 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 20/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9961 - loss: 0.1685 - precision: 0.9961 - recall: 0.9954 - val_accuracy: 0.9939 - val_loss: 0.1614 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 21/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9972 - loss: 0.1415 - precision: 0.9972 - recall: 0.9972 - val_accuracy: 0.9954 - val_loss: 0.1383 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 22/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9981 - loss: 0.1208 - precision: 0.9982 - recall: 0.9981 - val_accuracy: 0.9954 - val_loss: 0.1164 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 23/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.9976 - loss: 0.1086 - precision: 0.9976 - recall: 0.9973 - val_accuracy: 0.9939 - val_loss: 0.1144 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 24/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9966 - loss: 0.0968 - precision: 0.9971 - recall: 0.9965 - val_accuracy: 0.9954 - val_loss: 0.0893 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 25/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9979 - loss: 0.0846 - precision: 0.9985 - recall: 0.9978 - val_accuracy: 0.9969 - val_loss: 0.0810 - val_precision: 0.9969 - val_recall: 0.9954
# Epoch 26/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9987 - loss: 0.0735 - precision: 0.9987 - recall: 0.9987 - val_accuracy: 0.9954 - val_loss: 0.0880 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 27/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 215ms/step - accuracy: 0.9989 - loss: 0.0665 - precision: 0.9989 - recall: 0.9984 - val_accuracy: 0.9954 - val_loss: 0.0727 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 28/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.9970 - loss: 0.0653 - precision: 0.9980 - recall: 0.9957 - val_accuracy: 0.9939 - val_loss: 0.0797 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 29/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9960 - loss: 0.0615 - precision: 0.9961 - recall: 0.9957 - val_accuracy: 0.9954 - val_loss: 0.0671 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 30/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 215ms/step - accuracy: 0.9984 - loss: 0.0520 - precision: 0.9984 - recall: 0.9984 - val_accuracy: 0.9924 - val_loss: 0.0631 - val_precision: 0.9939 - val_recall: 0.9924
# Epoch 31/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.9976 - loss: 0.0487 - precision: 0.9976 - recall: 0.9976 - val_accuracy: 0.9954 - val_loss: 0.0657 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 32/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9989 - loss: 0.0440 - precision: 0.9989 - recall: 0.9985 - val_accuracy: 0.9954 - val_loss: 0.0598 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 33/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.9988 - loss: 0.0424 - precision: 0.9988 - recall: 0.9988 - val_accuracy: 0.9939 - val_loss: 0.0636 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 34/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9973 - loss: 0.0433 - precision: 0.9976 - recall: 0.9968 - val_accuracy: 0.9939 - val_loss: 0.0639 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 35/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9986 - loss: 0.0385 - precision: 0.9986 - recall: 0.9982 - val_accuracy: 0.9939 - val_loss: 0.0677 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 36/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.9994 - loss: 0.0359 - precision: 0.9995 - recall: 0.9992 - val_accuracy: 0.9954 - val_loss: 0.0500 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 37/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9984 - loss: 0.0368 - precision: 0.9984 - recall: 0.9984 - val_accuracy: 0.9954 - val_loss: 0.0499 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 38/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9978 - loss: 0.0384 - precision: 0.9978 - recall: 0.9978 - val_accuracy: 0.9954 - val_loss: 0.0490 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 39/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.9985 - loss: 0.0339 - precision: 0.9985 - recall: 0.9985 - val_accuracy: 0.9954 - val_loss: 0.0577 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 40/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9981 - loss: 0.0331 - precision: 0.9985 - recall: 0.9980 - val_accuracy: 0.9939 - val_loss: 0.0577 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 41/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9990 - loss: 0.0315 - precision: 0.9990 - recall: 0.9990 - val_accuracy: 0.9954 - val_loss: 0.0483 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 42/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9969 - loss: 0.0358 - precision: 0.9969 - recall: 0.9969 - val_accuracy: 0.9954 - val_loss: 0.0509 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 43/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9992 - loss: 0.0293 - precision: 0.9992 - recall: 0.9988 - val_accuracy: 0.9954 - val_loss: 0.0443 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 44/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9983 - loss: 0.0300 - precision: 0.9987 - recall: 0.9983 - val_accuracy: 0.9954 - val_loss: 0.0496 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 45/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9992 - loss: 0.0279 - precision: 0.9992 - recall: 0.9992 - val_accuracy: 0.9939 - val_loss: 0.0482 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 46/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9994 - loss: 0.0281 - precision: 0.9994 - recall: 0.9991 - val_accuracy: 0.9939 - val_loss: 0.0556 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 47/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9994 - loss: 0.0270 - precision: 0.9994 - recall: 0.9994 - val_accuracy: 0.9954 - val_loss: 0.0535 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 48/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9991 - loss: 0.0267 - precision: 0.9991 - recall: 0.9991 - val_accuracy: 0.9939 - val_loss: 0.0516 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 49/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9976 - loss: 0.0269 - precision: 0.9976 - recall: 0.9976 - val_accuracy: 0.9954 - val_loss: 0.0442 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 50/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9988 - loss: 0.0261 - precision: 0.9989 - recall: 0.9986 - val_accuracy: 0.9939 - val_loss: 0.0549 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 51/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9986 - loss: 0.0261 - precision: 0.9986 - recall: 0.9986 - val_accuracy: 0.9939 - val_loss: 0.0548 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 52/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9987 - loss: 0.0261 - precision: 0.9990 - recall: 0.9985 - val_accuracy: 0.9969 - val_loss: 0.0395 - val_precision: 0.9969 - val_recall: 0.9969
# Epoch 53/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9977 - loss: 0.0286 - precision: 0.9979 - recall: 0.9977 - val_accuracy: 0.9939 - val_loss: 0.0493 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 54/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9999 - loss: 0.0235 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9939 - val_loss: 0.0538 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 55/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9987 - loss: 0.0239 - precision: 0.9987 - recall: 0.9985 - val_accuracy: 0.9939 - val_loss: 0.0495 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 56/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9990 - loss: 0.0240 - precision: 0.9992 - recall: 0.9990 - val_accuracy: 0.9939 - val_loss: 0.0487 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 57/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9991 - loss: 0.0241 - precision: 0.9991 - recall: 0.9991 - val_accuracy: 0.9939 - val_loss: 0.0462 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 58/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.9998 - loss: 0.0216 - precision: 0.9998 - recall: 0.9998 - val_accuracy: 0.9939 - val_loss: 0.0474 - val_precision: 0.9939 - val_recall: 0.9939
# Epoch 59/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.9993 - loss: 0.0230 - precision: 0.9994 - recall: 0.9993 - val_accuracy: 0.9954 - val_loss: 0.0476 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 60/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9998 - loss: 0.0215 - precision: 0.9998 - recall: 0.9998 - val_accuracy: 0.9954 - val_loss: 0.0472 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 61/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.9992 - loss: 0.0223 - precision: 0.9992 - recall: 0.9992 - val_accuracy: 0.9939 - val_loss: 0.0464 - val_precision: 0.9954 - val_recall: 0.9939
# Epoch 62/1000
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.9998 - loss: 0.0215 - precision: 0.9998 - recall: 0.9998 - val_accuracy: 0.9954 - val_loss: 0.0462 - val_precision: 0.9954 - val_recall: 0.9939

# %% [markdown]
# # Visualize model performance

# %%
hist.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'precision', 'recall', 'val_accuracy', 'val_loss', 'val_precision', 'val_recall'])

# %%
tr_acc = hist.history['accuracy']
tr_loss = hist.history['loss']
tr_per = hist.history['precision']
tr_recall = hist.history['recall']
val_acc = hist.history['val_accuracy']
val_loss = hist.history['val_loss']
val_per = hist.history['val_precision']
val_recall = hist.history['val_recall']

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
index_precision = np.argmax(val_per)
per_highest = val_per[index_precision]
index_recall = np.argmax(val_recall)
recall_highest = val_recall[index_recall]

Epochs = [i + 1 for i in range(len(tr_acc))]
loss_label = f'Best epoch = {str(index_loss + 1)}'
acc_label = f'Best epoch = {str(index_acc + 1)}'
per_label = f'Best epoch = {str(index_precision + 1)}'
recall_label = f'Best epoch = {str(index_recall + 1)}'


plt.figure(figsize=(20, 12))
plt.style.use('fivethirtyeight')


plt.subplot(2, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label='Training loss')
plt.plot(Epochs, val_loss, 'g', label='Validation loss')
plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label='Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy')
plt.scatter(index_acc + 1, acc_highest, s=150, c='blue', label=acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(Epochs, tr_per, 'r', label='Precision')
plt.plot(Epochs, val_per, 'g', label='Validation Precision')
plt.scatter(index_precision + 1, per_highest, s=150, c='blue', label=per_label)
plt.title('Precision and Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(Epochs, tr_recall, 'r', label='Recall')
plt.plot(Epochs, val_recall, 'g', label='Validation Recall')
plt.scatter(index_recall + 1, recall_highest, s=150, c='blue', label=recall_label)
plt.title('Recall and Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.grid(True)

plt.suptitle('Model Training Metrics Over Epochs', fontsize=16)
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
train_score = model.evaluate(tr_gen, verbose=1)
valid_score = model.evaluate(valid_gen, verbose=1)
test_score = model.evaluate(ts_gen, verbose=1)

print(f"Train Loss: {train_score[0]:.4f}")
print(f"Train Accuracy: {train_score[1]*100:.2f}%")
print('-' * 20)
print(f"Validation Loss: {valid_score[0]:.4f}")
print(f"Validation Accuracy: {valid_score[1]*100:.2f}%")
print('-' * 20)
print(f"Test Loss: {test_score[0]:.4f}")
print(f"Test Accuracy: {test_score[1]*100:.2f}%")

print(test_score)
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.9995 - loss: 0.0212 - precision: 1.0000 - recall: 0.9993
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9992 - loss: 0.0255 - precision: 0.9992 - recall: 0.9992
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9990 - loss: 0.0220 - precision: 0.9990 - recall: 0.9990
# Train Loss: 0.0214
# Train Accuracy: 99.95%
# --------------------
# Validation Loss: 0.0395
# Validation Accuracy: 99.69%
# --------------------
# Test Loss: 0.0236
# Test Accuracy: 99.85%
# [0.0236057098954916, 0.9984756112098694, 0.9984756112098694, 0.9984756112098694]

# %%
preds = model.predict(ts_gen)
y_pred = np.argmax(preds, axis=1)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step

# %% [markdown]
# # Confusion matrix

# %%
cm = confusion_matrix(ts_gen.classes, y_pred)
labels = list(class_dict.keys())
plt.figure(figsize=(8,7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('Truth Label')
plt.show()

# %% [markdown]
# # Classification report

# %%
report = classification_report(ts_gen.classes, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       150
#            1       0.99      1.00      1.00       153
#            2       1.00      1.00      1.00       203
#            3       1.00      1.00      1.00       150
#
#     accuracy                           1.00       656
#    macro avg       1.00      1.00      1.00       656
# weighted avg       1.00      1.00      1.00       656

# %% [markdown]
# # Testing

# %%
def predict(img_path):
    import numpy as np
    import matplotlib.pyplot as plt
    from PIL import Image
    from tensorflow.keras.applications.efficientnet import preprocess_input

    # Generator label order
    labels = list(tr_gen.class_indices.keys())

    plt.figure(figsize=(12, 12))
    img = Image.open(img_path).convert('RGB')
    resized_img = img.resize((300, 300))
    img = np.asarray(resized_img)
    img = np.expand_dims(img, axis=0)

    img = preprocess_input(img)

    predictions = model.predict(img)
    probs = list(predictions[0])

    # Plotting
    plt.subplot(2, 1, 1)
    plt.imshow(resized_img)
    plt.axis('off')
    plt.title("Input Image")

    plt.subplot(2, 1, 2)
    bars = plt.barh(labels, probs, color='skyblue')
    plt.xlabel('Probability', fontsize=15)
    plt.title("Class Probabilities")
    ax = plt.gca()
    ax.bar_label(bars, fmt='%.2f')
    plt.tight_layout()
    plt.show()

# %%
predict('/home/readinggroup/Desktop/K_venv/dl/MRI/Testing/notumor/Te-noTr_0000.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
predict('/home/readinggroup/Desktop/K_venv/dl/MRI/Testing/glioma/Te-glTr_0000.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
predict('/home/readinggroup/Desktop/K_venv/dl/MRI/Testing/pituitary/Te-piTr_0008.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
from numba import cuda
device = cuda.get_current_device()
device.reset()
